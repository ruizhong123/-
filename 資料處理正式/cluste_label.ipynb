# %%
import pandas as pd 

data = pd.read_excel(r'C:\資料探勘\資料處理正式\entire_data.xlsx')

# %%
data['主建物占比'] = data['主建物占比'].round(4)
data['附屬面積占比'] = data['附屬面積占比'].round(4)
data['陽台面積占比'] = data['陽台面積(坪)'].round(4)
data['公佔比'] = data['公佔比'].round(4)

# %%
data['交易標的'].value_counts()
data = data[data['交易標的'] != '車位']

# %%
data['屋齡'] = data['屋齡'].dropna()
data['第一筆樓層數'] = data['第一筆樓層數'].dropna()

# %%
cluster_matrix = data[['土地移轉總面積(坪)', '交易筆棟數', '建物現況格局.房', '建物現況格局.廳',
       '建物現況格局.衛', '建物現況格局.隔間',  '單價(萬/坪)','建物移轉總面積(坪)',
       '車位移轉總面積(坪)', '車位總價元(萬)', '總價元(萬)','主建物占比', '陽台面積占比',
       '附屬面積占比', '公佔比','備註', '第一筆樓層數']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       1 cluster_matrix = data[['土地移轉總面積(坪)', '交易筆棟數', '建物現況格局.房', '建物現況格局.廳',
#       2        '建物現況格局.衛', '建物現況格局.隔間',  '單價(萬/坪)','建物移轉總面積(坪)',
#       3        '車位移轉總面積(坪)', '車位總價元(萬)', '總價元(萬)','主建物占比', '陽台面積占比',
#       4        '附屬面積占比', '公佔比','備註', '第一筆樓層數']]
# ----> 6 cluster_matrix.mean().head()
#
# File c:\Users\ruizhong\anaconda3\envs\myenv\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# ...

# %%
cluster_matrix = data[['土地移轉總面積(坪)', '交易筆棟數', '建物現況格局.房', '建物現況格局.廳',
       '建物現況格局.衛', '建物現況格局.隔間',  '單價(萬/坪)','建物移轉總面積(坪)',
       '車位移轉總面積(坪)', '車位總價元(萬)', '總價元(萬)','主建物占比', '陽台面積占比',
       '附屬面積占比', '公佔比','備註', '第一筆樓層數']]

cluster_matrix.mean()
