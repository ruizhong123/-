# %%
import pandas as pd 

data112= pd.read_excel(r'C:\資料探勘\經緯度資料標記\112_label_.xlsx')

# %%
data112.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20476 entries, 0 to 20475
# Data columns (total 37 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   鄉鎮市區         20476 non-null  object
#  1   交易標的         20476 non-null  object
#  2   土地位置建物門牌     20476 non-null  object
#  3   土地移轉總面積平方公尺  20476 non-null  float64
#  4   都市土地使用分區     20041 non-null  object
#  5   非都市土地使用分區    1 non-null      object
#  6   非都市土地使用編定    0 non-null      float64
#  7   交易年月日        20476 non-null  int64
#  8   交易筆棟數        20476 non-null  object
#  9   移轉層次         20292 non-null  object
#  10  總樓層數         20274 non-null  object
#  11  建物型態         20476 non-null  object
#  12  主要用途         19699 non-null  object
#  13  主要建材         20292 non-null  object
#  14  建築完成年月       19544 non-null  float64
#  15  建物移轉總面積平方公尺  20476 non-null  float64
#  16  建物現況格局.房     20476 non-null  int64
#  17  建物現況格局.廳     20476 non-null  int64
# ...

# %%
data112['交易標的'].value_counts()
# Out:
# 交易標的
# 房地(土地+建物)       13983
# 房地(土地+建物)+車位     5312
# 車位               1026
# 建物                155
# Name: count, dtype: int64

# %%
data112['主要建材'].value_counts()
# Out:
# 主要建材
# 鋼筋混凝土造             17870
# 加強磚造                1099
# 鋼骨造                  544
# 鋼骨鋼筋混凝土造             521
# 磚造                    96
# 見使用執照                 54
# 鋼骨混凝土造                27
# 鋼骨鋼筋混凝土造；鋼骨造          14
# 木造                    12
# 預力混凝土造                11
# 壁式預鑄鋼筋混凝土造             5
# 土磚石混合造                 5
# 土造                     4
# 木石磚造（磚石造）              3
# 鋼筋混凝土結構造               3
# 磚石造                    3
# 土木造                    3
# 木石磚造                   2
# 鋼骨ＲＣ造                  2
# 鋼構造                    2
# 鋼筋混凝土加強磚造              2
# 鋼造                     2
# 磚造土造                   1
# 石造                     1
# 鋼骨造、鋼骨鋼筋混凝土造           1
# 加強磚                    1
# 鋼筋混凝土造，鋼骨鋼筋混凝土造        1
# 加強磚造、輕鋼架               1
# 混凝土造                   1
# ＲＣ造                    1
# Name: count, dtype: int64

# %%
pd.set_option('display.max_row',None)
data112['主要用途'].value_counts()
# Out:
# 主要用途
# 住家用                   14991
# 商業用                    2442
# 其他                      583
# 辦公用                     556
# 工業用                     219
# 停車空間                    214
# 見使用執照                   166
# 住商用                     138
# 一般事務所                   126
# 防空避難室兼停車場                33
# 一般零售業                    30
# 一般零售業甲組                  21
# 一般零售業（甲組）                18
# 日常服務業                    14
# 工商用                      14
# 農業用                      12
# 日常用品零售業                  10
# 住工用                       8
# 策略性產業〈２８組資訊服務業〉           7
# 自由職業事務所                   6
# 一般零售業甲組（不含日用百貨）           6
# 一般零售業〈甲組〉                 6
# 日常用品零售業不含便利商店             6
# 一般事務所（Ｇ２）                 5
# 停車場、防空避難室兼停車場             4
# 多戶住宅                      4
# 集合住宅                      3
# 一般事務所（Ｇ３）                 3
# 防空避難室、停車場                 3
# 一般零售業乙組                   3
# 一般零售業﹝甲組﹞                 3
# 商辦用                       3
# 防空避難室兼商場、停車場              2
# ...

# %%
print(data112['備註'].value_counts())
# Out:
# 備註
# 其他增建；                                                                                                                                                                                                                       2295
# 陽台外推；其他增建；                                                                                                                                                                                                                  2055
# 親友、員工、共有人或其他特殊關係間之交易；                                                                                                                                                                                                       1974
# 陽台外推；                                                                                                                                                                                                                       1822
# ...

# %%
data112['建物型態'].value_counts()
# Out:
# 建物型態
# 住宅大樓(11層含以上有電梯)    7711
# 公寓(5樓含以下無電梯)       6053
# 華廈(10層含以下有電梯)      5164
# 其他                 1026
# 透天厝                 521
# 廠辦                    1
# Name: count, dtype: int64

# %%
data112['建物現況格局.隔間'].value_counts()
# Out:
# 建物現況格局.隔間
# 有    17829
# 無     2647
# Name: count, dtype: int64

# %%
data112['有無管理組織'].value_counts()
# Out:
# 有無管理組織
# 有    12991
# 無     7485
# Name: count, dtype: int64

# %%
data112['都市土地使用分區'].value_counts()
# Out:
# 都市土地使用分區
# 住                                                                                      11608
# 商                                                                                       6569
# 工                                                                                        408
# 都市：其他:第三種住宅區。                                                                            306
# 都市：其他:住宅用地(民生社區特定專用區)。                                                                   154
# 都市：其他:特定觀光商業專用區。                                                                         126
# 都市：其他:特定業務區(信義計畫特定專用區)。                                                                   91
# 都市：其他:特定專用區(供一般商業使用)。                                                                     51
# 都市：其他:特定休閒旅館住宅專用區。                                                                        46
# 都市：其他:住宅用地(民生社區特定專用區) 但是否在道路用地(公共設施用地)(應依建築線或俟地籍測量分割後，再確定)。                               44
# ...

# %%
data112['非都市土地使用分區'].value_counts()
# Out:
# 非都市土地使用分區
# 住宅區    1
# Name: count, dtype: int64

# %%
data112['電梯'].value_counts()
# Out:
# 電梯
# 有    13802
# 無     6674
# Name: count, dtype: int64

# %%
data112['']

# %%
data112['非都市土地使用編定'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)
